# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
survey_df = pd.read_csv('survey_results_public.csv')
survey_scemha_df = pd.read_csv('survey_results_schema.csv')

# %%
survey_df.head()
survey_scemha_df.head()

# %%
survey_scemha_df.set_index('Column', inplace=True)

# %%
schema_raw = survey_scemha_df['QuestionText']
schema_raw

# %%
survey_df.info()

# %%
survey_df['Age1stCode'] =pd.to_numeric(survey_df['Age1stCode'])

# %%
survey_df.drop(survey_df[survey_df.Age<10].index, inplace= True)

# %%
survey_df.where(~(survey_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)
